# %%
import statistics
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter

# %%
N = 1

Np_1_Nc_1 =	    [9.12681500,    9.02555400,	    9.28009600,	    9.390122000,	9.263891000,	10.50079900,	9.506644000,	9.520955000,	9.339815000,	10.13727300]
Np_1_Nc_2 =     [11.97521100,	12.20521800,	12.17470000,	12.58408400,	12.08693300,	12.19062900,	12.29418100,	12.26253000,	11.98691400,	12.24545200]
Np_1_Nc_4	=   [12.92776900,	13.05232400,	12.77398500,	12.75111000,	12.78388800,	12.90343900,	12.92804600,	12.81563400,	12.56462100,	12.63554200]
Np_1_Nc_8	=   [12.63503500,	12.57050000,	12.59347200,	12.75590000,	12.60056200,	12.66288900,	12.75041500,	12.78172200,	12.65807400,	12.57946700]
Np_2_Nc_1	=   [9.10411500,    9.23582800,	    9.07066200,	    8.975086000,	9.084879000,	9.245593000,	9.452045000,	9.132432000,	9.153878000,	9.162195000]
Np_4_Nc_1	=   [9.31905100,    9.08345600,	    9.16711200,	    9.071706000,	9.187855000,	9.168413000,	9.254648000,	9.162582000,	9.171749000,	9.461018000]
Np_8_Nc_1	=   [9.17934900,    9.31101700,	    9.22457500,	    9.285667000,	9.212739000,	9.310021000,	9.252911000,	9.248153000,	9.453298000,	9.249400000]

lista_variaveis = [Np_1_Nc_1, Np_1_Nc_2, Np_1_Nc_4, Np_1_Nc_8, Np_2_Nc_1, Np_4_Nc_1, Np_8_Nc_1]

medias = []
for i in range(len(lista_variaveis)):
    medias.append(sum(lista_variaveis[i])/len(lista_variaveis[i]))

st_dev = []
for i in range(len(lista_variaveis)):
    st_dev.append(statistics.pstdev(lista_variaveis[i]))

pares = [[1,1], [1,2], [1,4], [1,8], [2,1], [4,1], [8,1]]

data = []
for i in range(len(pares)):
    data.append([pares[i][0], pares[i][1],medias[i], st_dev[i]])

df = pd.DataFrame(data, columns=['Np', 'Nc', 'media', 'st_dev'])
print(df)
# Out:
#    Np  Nc      media    st_dev
# 0   1   1   9.509196  0.437442
# 1   1   2  12.200585  0.164875
# 2   1   4  12.813636  0.138293
# 3   1   8  12.658804  0.074339
# 4   2   1   9.161671  0.122508
# 5   4   1   9.204759  0.109330
# 6   8   1   9.272713  0.071978

# %%
fig, ax = plt.subplots()
width = 0.35

# Definindo as cores para cada barra
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink']

# Configurando as posições das barras
x = np.arange(len(df))

# Plot das barras de média
ax.bar(x, df['media'], width, yerr=df['st_dev'], alpha=0.7, color=colors, label=[(row['Np'], row['Nc']) for _, row in df.iterrows()])

# Configuração dos eixos e legendas
ax.set_ylabel('Tempo (s)')
ax.set_xlabel('Pares (Np, Nc)')
ax.set_title(f'N = {N}')
ax.set_xticks(x)
ax.set_xticklabels([(int(row['Np']), int(row['Nc'])) for _, row in df.iterrows()])

plt.show()

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_1_Np_1_Nc_1.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')
df.plot(kind='bar')
plt.xlabel('Valor')
plt.ylabel('Frequência')
plt.title('Histograma N=1, Np = 1 e Nc = 1')
plt.legend().remove()

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_1_Np_1_Nc_2.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')
df.plot(kind='bar')
plt.xlabel('Valor')
plt.ylabel('Frequência')
plt.title('Histograma N=1, Np = 1 e Nc = 2')
plt.legend().remove()

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_1_Np_1_Nc_4.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')
df.plot(kind='bar')
plt.xlabel('Valor')
plt.ylabel('Frequência')
plt.title('Histograma N=1, Np = 1 e Nc = 4')
plt.legend().remove()

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_1_Np_1_Nc_8.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')
df.plot(kind='bar')
plt.xlabel('Valor')
plt.ylabel('Frequência')
plt.title('Histograma N=1, Np = 1 e Nc = 8')
plt.legend().remove()

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_1_Np_2_Nc_1.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')
df.plot(kind='bar')
plt.xlabel('Valor')
plt.ylabel('Frequência')
plt.title('Histograma N=1, Np = 2 e Nc = 1')
plt.legend().remove()

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_1_Np_4_Nc_1.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')
df.plot(kind='bar')
plt.xlabel('Valor')
plt.ylabel('Frequência')
plt.title('Histograma N=1, Np = 4 e Nc = 1')
plt.legend().remove()

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_1_Np_8_Nc_1.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')
df.plot(kind='bar')
plt.xlabel('Valor')
plt.ylabel('Frequência')
plt.title('Histograma N=1, Np = 8 e Nc = 1')
plt.legend().remove()

# %%
N = 10

Np_1_Nc_1	=   [7.803754000,    7.827474000,	7.835352000,	7.712698000,	7.906310000,	7.921968000,	7.784196000,	7.838219000,	7.781692000,	7.84078200]
Np_1_Nc_2	=   [15.55272400,	15.41834600,	15.61630700,	15.52852100,	15.61898000,	15.54411500,	15.77318800,	15.51830800,	15.48277000,	15.63948200]
Np_1_Nc_4	=   [14.15783300,	14.22853500,	14.49964600,	14.19650900,	14.02978100,	14.12946000,	14.28168000,	14.57356400,	14.40894900,	14.18466900]
Np_1_Nc_8	=   [14.21007400,	14.35199400,	14.49181100,	14.23767200,	14.53495800,	14.41114900,	14.37320400,	14.34090500,	14.32445200,	14.44178800]
Np_2_Nc_1	=   [8.644861000,    8.614866000,	8.625796000,	8.510092000,	8.451162000,	8.575133000,	8.562362000,	8.696156000,	8.514934000,	8.71718400]
Np_4_Nc_1	=   [8.541793000,    8.751526000,	8.795509000,	8.776329000,	9.012390000,	8.833023000,	8.708975000,	8.700970000,	8.646775000,	8.59092400]
Np_8_Nc_1	=   [8.848716000,    8.748654000,	8.784205000,	9.049225000,	8.918161000,	8.735895000,	9.068031000,	8.755146000,	8.793080000,	8.77523500]

lista_variaveis = [Np_1_Nc_1, Np_1_Nc_2, Np_1_Nc_4, Np_1_Nc_8, Np_2_Nc_1, Np_4_Nc_1, Np_8_Nc_1]

medias = []
for i in range(len(lista_variaveis)):
    medias.append(sum(lista_variaveis[i])/len(lista_variaveis[i]))

st_dev = []
for i in range(len(lista_variaveis)):
    st_dev.append(statistics.pstdev(lista_variaveis[i]))

pares = [[1,1], [1,2], [1,4], [1,8], [2,1], [4,1], [8,1]]

data = []
for i in range(len(pares)):
    data.append([pares[i][0], pares[i][1],medias[i], st_dev[i]])

df = pd.DataFrame(data, columns=['Np', 'Nc', 'media', 'st_dev'])
print(df)
# Out:
#    Np  Nc      media    st_dev
# 0   1   1   7.825245  0.057580
# 1   1   2  15.569274  0.093070
# 2   1   4  14.269063  0.163940
# 3   1   8  14.371801  0.097574
# 4   2   1   8.591255  0.080386
# 5   4   1   8.735821  0.126450
# 6   8   1   8.847635  0.117161

# %%
fig, ax = plt.subplots()
width = 0.35

# Definindo as cores para cada barra
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink']

# Configurando as posições das barras
x = np.arange(len(df))

# Plot das barras de média
ax.bar(x, df['media'], width, yerr=df['st_dev'], alpha=0.7, color=colors, label=[(row['Np'], row['Nc']) for _, row in df.iterrows()])

# Configuração dos eixos e legendas
ax.set_ylabel('Tempo (s)')
ax.set_xlabel('Pares (Np, Nc)')
ax.set_title(f'N = {N}')
ax.set_xticks(x)
ax.set_xticklabels([(int(row['Np']), int(row['Nc'])) for _, row in df.iterrows()])

plt.show()

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_10_Np_1_Nc_1.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')
df.plot(kind='bar')
plt.xlabel('Valor')
plt.ylabel('Frequência')
plt.title('Histograma N=10, Np = 1 e Nc = 1')
plt.legend().remove()

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_10_Np_1_Nc_2.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')
df.plot(kind='bar')
plt.xlabel('Valor')
plt.ylabel('Frequência')
plt.title('Histograma N=10, Np = 1 e Nc = 2')
plt.legend().remove()

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_10_Np_1_Nc_4.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')
df.plot(kind='bar')
plt.xlabel('Valor')
plt.ylabel('Frequência')
plt.title('Histograma N=10, Np = 1 e Nc = 4')
# Ocultar a legenda
plt.legend().remove()

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_10_Np_1_Nc_8.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')
df.plot(kind='bar')
plt.xlabel('Valor')
plt.ylabel('Frequência')
plt.title('Histograma N=10, Np = 1 e Nc = 8')
# Ocultar a legenda
plt.legend().remove()

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_10_Np_2_Nc_1.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')
df.plot(kind='bar')
plt.xlabel('Valor')
plt.ylabel('Frequência')
plt.title('Histograma N=10, Np = 2 e Nc = 1')
# Ocultar a legenda
plt.legend().remove()

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_10_Np_4_Nc_1.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')
df.plot(kind='bar')
plt.xlabel('Valor')
plt.ylabel('Frequência')
plt.title('Histograma N=10, Np = 4 e Nc = 1')
# Ocultar a legenda
plt.legend().remove()

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_10_Np_8_Nc_1.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')
df.plot(kind='bar')
plt.xlabel('Valor')
plt.ylabel('Frequência')
plt.title('Histograma N=10, Np = 8 e Nc = 1')
# Ocultar a legenda
plt.legend().remove()

# %%
N = 100

Np_1_Nc_1	=[7.82369100,	7.63211700,	7.79586000,	7.65006600,	7.58480200,	7.52678200,	7.44136500,	7.50932200,	7.61637700,	7.78234400]
Np_1_Nc_2	=[14.77707100,	15.15392600,	14.72744900,	15.03667000,	14.46186500,	15.33546900,	15.31770500,	15.61062600,	15.80699000,	15.49296400]
Np_1_Nc_4	=[12.27078100,	12.94308700,	12.30221200,	12.23442900,	12.56777100,	12.45767000,	12.32648200,	12.50111100,	12.60916900,	12.81091500]
Np_1_Nc_8	=[13.62737200,	13.50214000,	14.11864300,	14.12000700,	13.96178700,	14.06375900,	14.19721500,	13.79201100,	13.49652100,	13.69681700]
Np_2_Nc_1	=[8.35233300,	8.83327500,	8.76313300,	8.93606000,	8.81105800,	9.00438900,	8.79185500,	8.90323400,	9.13222300,	8.75517400]
Np_4_Nc_1	=[8.52607900,	9.19992200,	8.97651600,	9.04573000,	9.03889900,	8.99678200,	9.10410300,	9.04584300,	8.94829100,	8.99513300]
Np_8_Nc_1	=[8.72548800,	9.03313200,	9.03808700,	9.10188000,	9.19245800,	9.05158700,	9.41671700,	9.08299800,	9.13118900,	9.07842300]

lista_variaveis = [Np_1_Nc_1, Np_1_Nc_2, Np_1_Nc_4, Np_1_Nc_8, Np_2_Nc_1, Np_4_Nc_1, Np_8_Nc_1]

medias = []
for i in range(len(lista_variaveis)):
    medias.append(sum(lista_variaveis[i])/len(lista_variaveis[i]))

st_dev = []
for i in range(len(lista_variaveis)):
    st_dev.append(statistics.pstdev(lista_variaveis[i]))

pares = [[1,1], [1,2], [1,4], [1,8], [2,1], [4,1], [8,1]]

data = []
for i in range(len(pares)):
    data.append([pares[i][0], pares[i][1],medias[i], st_dev[i]])

df = pd.DataFrame(data, columns=['Np', 'Nc', 'media', 'st_dev'])
print(df)
# Out:
#    Np  Nc      media    st_dev
# 0   1   1   7.636273  0.122995
# 1   1   2  15.172074  0.402877
# 2   1   4  12.502363  0.224397
# 3   1   8  13.857627  0.254083
# 4   2   1   8.828273  0.194523
# 5   4   1   8.987730  0.168187
# 6   8   1   9.085196  0.161030

# %%
fig, ax = plt.subplots()
width = 0.35

# Definindo as cores para cada barra
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink']

# Configurando as posições das barras
x = np.arange(len(df))

# Plot das barras de média
ax.bar(x, df['media'], width, yerr=df['st_dev'], alpha=0.7, color=colors, label=[(row['Np'], row['Nc']) for _, row in df.iterrows()])

# Configuração dos eixos e legendas
ax.set_ylabel('Tempo (s)')
ax.set_xlabel('Pares (Np, Nc)')
ax.set_title(f'N = {N}')
ax.set_xticks(x)
ax.set_xticklabels([(int(row['Np']), int(row['Nc'])) for _, row in df.iterrows()])

plt.show()

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_100_Np_1_Nc_1.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')

# Definir os intervalos para agrupar os valores
intervalos = []
for i in range(26):
    intervalos.append(i*N/(25))
intervalos[-1] +=1 

# Agrupar os valores usando pd.cut
grupos = pd.cut(content, bins=intervalos, right=False)

# Contar a frequência dos grupos
grupo_counts = grupos.value_counts()

# Plotar o histograma com os grupos
grupo_counts.plot(kind='bar')


plt.xlabel('Grupo')
plt.ylabel('Frequência')
plt.title('Histograma com grupos para N=100, Np = 1 e Nc = 1')
# Ocultar a legenda
plt.legend().remove()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_100_Np_1_Nc_2.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')

# Definir os intervalos para agrupar os valores
intervalos = []
for i in range(26):
    intervalos.append(i*N/(25))
intervalos[-1] +=1 

# Agrupar os valores usando pd.cut
grupos = pd.cut(content, bins=intervalos, right=False)

# Contar a frequência dos grupos
grupo_counts = grupos.value_counts()

# Plotar o histograma com os grupos
grupo_counts.plot(kind='bar')


plt.xlabel('Grupo')
plt.ylabel('Frequência')
plt.title('Histograma com grupos para N=100, Np = 1 e Nc = 2')
# Ocultar a legenda
plt.legend().remove()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_100_Np_1_Nc_4.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')

# Definir os intervalos para agrupar os valores
intervalos = []
for i in range(26):
    intervalos.append(i*N/(25))
intervalos[-1] +=1 

# Agrupar os valores usando pd.cut
grupos = pd.cut(content, bins=intervalos, right=False)

# Contar a frequência dos grupos
grupo_counts = grupos.value_counts()

# Plotar o histograma com os grupos
grupo_counts.plot(kind='bar')


plt.xlabel('Grupo')
plt.ylabel('Frequência')
plt.title('Histograma com grupos para N=100, Np = 1 e Nc = 4')
# Ocultar a legenda
plt.legend().remove()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_100_Np_1_Nc_8.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')

# Definir os intervalos para agrupar os valores
intervalos = []
for i in range(26):
    intervalos.append(i*N/(25))
intervalos[-1] +=1 

# Agrupar os valores usando pd.cut
grupos = pd.cut(content, bins=intervalos, right=False)

# Contar a frequência dos grupos
grupo_counts = grupos.value_counts()

# Plotar o histograma com os grupos
grupo_counts.plot(kind='bar')


plt.xlabel('Grupo')
plt.ylabel('Frequência')
plt.title('Histograma com grupos para N=100, Np = 1 e Nc = 8')
# Ocultar a legenda
plt.legend().remove()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_100_Np_2_Nc_1.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')

# Definir os intervalos para agrupar os valores
intervalos = []
for i in range(26):
    intervalos.append(i*N/(25))
intervalos[-1] +=1 

# Agrupar os valores usando pd.cut
grupos = pd.cut(content, bins=intervalos, right=False)

# Contar a frequência dos grupos
grupo_counts = grupos.value_counts()

# Plotar o histograma com os grupos
grupo_counts.plot(kind='bar')


plt.xlabel('Grupo')
plt.ylabel('Frequência')
plt.title('Histograma com grupos para N=100, Np = 2 e Nc = 1')
# Ocultar a legenda
plt.legend().remove()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_100_Np_4_Nc_1.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')

# Definir os intervalos para agrupar os valores
intervalos = []
for i in range(26):
    intervalos.append(i*N/(25))
intervalos[-1] +=1 

# Agrupar os valores usando pd.cut
grupos = pd.cut(content, bins=intervalos, right=False)

# Contar a frequência dos grupos
grupo_counts = grupos.value_counts()

# Plotar o histograma com os grupos
grupo_counts.plot(kind='bar')


plt.xlabel('Grupo')
plt.ylabel('Frequência')
plt.title('Histograma com grupos para N=100, Np = 4 e Nc = 1')
# Ocultar a legenda
plt.legend().remove()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_100_Np_8_Nc_1.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')

# Definir os intervalos para agrupar os valores
intervalos = []
for i in range(26):
    intervalos.append(i*N/(25))
intervalos[-1] +=1 

# Agrupar os valores usando pd.cut
grupos = pd.cut(content, bins=intervalos, right=False)

# Contar a frequência dos grupos
grupo_counts = grupos.value_counts()

# Plotar o histograma com os grupos
grupo_counts.plot(kind='bar')


plt.xlabel('Grupo')
plt.ylabel('Frequência')
plt.title('Histograma com grupos para N=100, Np = 8 e Nc = 1')
# Ocultar a legenda
plt.legend().remove()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
N = 1000

Np_1_Nc_1	=[7.68714400,	8.07677200,	7.87757900,	8.01729000,	8.04416500,	8.00067000,	7.93593200,	8.01595000,	7.76723400,	7.63369400]
Np_1_Nc_2	=[14.77410700,	15.36324000,	15.12834000,	14.99710400,	15.02520600,	15.05683200,	15.01312500,	14.82180100,	15.06679900,	15.14852800]
Np_1_Nc_4	=[12.02007300,	11.60421800,	11.70234100,	11.42229700,	11.52748800,	11.60101900,	11.47179000,	11.69197500,	11.66371100,	11.63641800]
Np_1_Nc_8	=[11.50429000,	11.15334200,	11.22974400,	11.09626700,	10.68206500,	11.15678200,	10.94167500,	11.05211800,	10.53962100,	10.90551200]
Np_2_Nc_1	=[8.53896000,	8.93305000,	8.79121200,	8.91194800,	8.85945000,	8.75460400,	8.74920300,	8.86619500,	8.83575600,	8.84048900]
Np_4_Nc_1	=[8.60236100,	8.98515400,	8.89006000,	9.10425500,	9.15335400,	9.37307700,	9.35715900,	8.94235800,	9.01244900,	9.04309800]
Np_8_Nc_1	=[8.77333800,	9.00605500,	9.26836100,	9.69006800,	9.18052900,	9.17978900,	9.04049300,	9.05953200,	9.02141000,	9.03235200]

lista_variaveis = [Np_1_Nc_1, Np_1_Nc_2, Np_1_Nc_4, Np_1_Nc_8, Np_2_Nc_1, Np_4_Nc_1, Np_8_Nc_1]

medias = []
for i in range(len(lista_variaveis)):
    medias.append(sum(lista_variaveis[i])/len(lista_variaveis[i]))

st_dev = []
for i in range(len(lista_variaveis)):
    st_dev.append(statistics.pstdev(lista_variaveis[i]))

pares = [[1,1], [1,2], [1,4], [1,8], [2,1], [4,1], [8,1]]

data = []
for i in range(len(pares)):
    data.append([pares[i][0], pares[i][1],medias[i], st_dev[i]])

df = pd.DataFrame(data, columns=['Np', 'Nc', 'media', 'st_dev'])
print(df)
# Out:
#    Np  Nc      media    st_dev
# 0   1   1   7.905643  0.149899
# 1   1   2  15.039508  0.156894
# 2   1   4  11.634133  0.155699
# 3   1   8  11.026142  0.261858
# 4   2   1   8.808087  0.106431
# 5   4   1   9.046333  0.213407
# 6   8   1   9.125193  0.226825

# %%
fig, ax = plt.subplots()
width = 0.35

# Definindo as cores para cada barra
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink']

# Configurando as posições das barras
x = np.arange(len(df))

# Plot das barras de média
ax.bar(x, df['media'], width, yerr=df['st_dev'], alpha=0.7, color=colors, label=[(row['Np'], row['Nc']) for _, row in df.iterrows()])

# Configuração dos eixos e legendas
ax.set_ylabel('Tempo (s)')
ax.set_xlabel('Pares (Np, Nc)')
ax.set_title(f'N = {N}')
ax.set_xticks(x)
ax.set_xticklabels([(int(row['Np']), int(row['Nc'])) for _, row in df.iterrows()])

plt.show()

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_1000_Np_1_Nc_1.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')

# Definir os intervalos para agrupar os valores
intervalos = []
for i in range(26):
    intervalos.append(i*N/(25))
intervalos[-1] +=1 

# Agrupar os valores usando pd.cut
grupos = pd.cut(content, bins=intervalos, right=False)

# Contar a frequência dos grupos
grupo_counts = grupos.value_counts()

# Plotar o histograma com os grupos
grupo_counts.plot(kind='bar')


plt.xlabel('Grupo')
plt.ylabel('Frequência')
plt.title('Histograma com grupos para N=1000, Np = 1 e Nc = 1')
# Ocultar a legenda
plt.legend().remove()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_1000_Np_1_Nc_2.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')

# Definir os intervalos para agrupar os valores
intervalos = []
for i in range(26):
    intervalos.append(i*N/(25))
intervalos[-1] +=1 

# Agrupar os valores usando pd.cut
grupos = pd.cut(content, bins=intervalos, right=False)

# Contar a frequência dos grupos
grupo_counts = grupos.value_counts()

# Plotar o histograma com os grupos
grupo_counts.plot(kind='bar')


plt.xlabel('Grupo')
plt.ylabel('Frequência')
plt.title('Histograma com grupos para N=1000, Np = 1 e Nc = 2')
# Ocultar a legenda
plt.legend().remove()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_1000_Np_1_Nc_4.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')

# Definir os intervalos para agrupar os valores
intervalos = []
for i in range(26):
    intervalos.append(i*N/(25))
intervalos[-1] +=1 

# Agrupar os valores usando pd.cut
grupos = pd.cut(content, bins=intervalos, right=False)

# Contar a frequência dos grupos
grupo_counts = grupos.value_counts()

# Plotar o histograma com os grupos
grupo_counts.plot(kind='bar')


plt.xlabel('Grupo')
plt.ylabel('Frequência')
plt.title('Histograma com grupos para N=1000, Np = 1 e Nc = 4')
# Ocultar a legenda
plt.legend().remove()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_1000_Np_1_Nc_8.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')

# Definir os intervalos para agrupar os valores
intervalos = []
for i in range(26):
    intervalos.append(i*N/(25))
intervalos[-1] +=1 

# Agrupar os valores usando pd.cut
grupos = pd.cut(content, bins=intervalos, right=False)

# Contar a frequência dos grupos
grupo_counts = grupos.value_counts()

# Plotar o histograma com os grupos
grupo_counts.plot(kind='bar')


plt.xlabel('Grupo')
plt.ylabel('Frequência')
plt.title('Histograma com grupos para N=1000, Np = 1 e Nc = 8')
# Ocultar a legenda
plt.legend().remove()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_1000_Np_2_Nc_1.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')

# Definir os intervalos para agrupar os valores
intervalos = []
for i in range(26):
    intervalos.append(i*N/(25))
intervalos[-1] +=1 

# Agrupar os valores usando pd.cut
grupos = pd.cut(content, bins=intervalos, right=False)

# Contar a frequência dos grupos
grupo_counts = grupos.value_counts()

# Plotar o histograma com os grupos
grupo_counts.plot(kind='bar')


plt.xlabel('Grupo')
plt.ylabel('Frequência')
plt.title('Histograma com grupos para N=1000, Np = 2 e Nc = 1')
# Ocultar a legenda
plt.legend().remove()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_1000_Np_4_Nc_1.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')

# Definir os intervalos para agrupar os valores
intervalos = []
for i in range(26):
    intervalos.append(i*N/(25))
intervalos[-1] +=1 

# Agrupar os valores usando pd.cut
grupos = pd.cut(content, bins=intervalos, right=False)

# Contar a frequência dos grupos
grupo_counts = grupos.value_counts()

# Plotar o histograma com os grupos
grupo_counts.plot(kind='bar')


plt.xlabel('Grupo')
plt.ylabel('Frequência')
plt.title('Histograma com grupos para N=1000, Np = 4 e Nc = 1')
# Ocultar a legenda
plt.legend().remove()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
file_path = r'C:\Users\wpett\OneDrive\Desktop\UFRJ\2023.1\Sistemas Distribuídos\Distributed Systems\Practical Task 2\Item 3\Histories\thread_history_N_1000_Np_8_Nc_1.txt'

with open(file_path, 'r') as file:
    content = file.read()

content = content.split(',')
content = [int(num) for num in content]

number_counts = Counter(content)
df = pd.DataFrame.from_dict(number_counts, orient='index')

# Definir os intervalos para agrupar os valores
intervalos = []
for i in range(26):
    intervalos.append(i*N/(25))
intervalos[-1] +=1 

# Agrupar os valores usando pd.cut
grupos = pd.cut(content, bins=intervalos, right=False)

# Contar a frequência dos grupos
grupo_counts = grupos.value_counts()

# Plotar o histograma com os grupos
grupo_counts.plot(kind='bar')


plt.xlabel('Grupo')
plt.ylabel('Frequência')
plt.title('Histograma com grupos para N=1000, Np = 8 e Nc = 1')
# Ocultar a legenda
plt.legend().remove()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
